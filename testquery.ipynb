# %%
import requests
import json
import time

url = "https://yale.downtownerapp.com/routes_buses.php"

while True:
    try:
        response = requests.get(url)
        if response.status_code == 200:
            data = json.loads(response.text)
            print(json.dumps(data, indent=4))
        else:
            print(f"Error: {response.status_code} - {response.text}")
    except requests.exceptions.RequestException as e:
        print(f"Error: {e}")
    break
# Out:
# [
#     {
#         "id": 20998,
#         "name": "#330",
#         "lat": 41.323018,
#         "lon": -72.913891,
#         "heading": 299,
#         "route": 9,
#         "lastStop": 143,
#         "lastUpdate": 1711555413
#     },
#     {
#         "id": 21002,
#         "name": "#314",
#         "lat": 41.255718,
#         "lon": -72.994077,
#         "heading": 202,
#         "route": 9,
#         "lastStop": 22,
#         "lastUpdate": 1711555414
#     },
#     {
#         "id": 21004,
#         "name": "#308",
#         "lat": 41.303727,
#         "lon": -72.93165,
#         "heading": 124,
#         "route": 8,
#         "lastStop": 72,
#         "lastUpdate": 1711555409
#     },
#     {
#         "id": 21005,
#         "name": "#329",
#         "lat": 41.255897,
#         "lon": -72.990143,
#         "heading": 216,
#         "route": 10,
#         "lastStop": 23,
#         "lastUpdate": 1711555414
#     },
#     {
#         "id": 21007,
#         "name": "#316",
#         "lat": 41.297921,
#         "lon": -72.926713,
#         "heading": 40,
#         "route": 12,
#         "lastStop": 98,
#         "lastUpdate": 1711555414
#     },
#     {
#         "id": 21008,
#         "name": "#317",
#         "lat": 41.324905,
#         "lon": -72.928296,
#         "heading": 343,
#         "route": 3,
#         "lastStop": 27,
#         "lastUpdate": 1711555408
#     },
#     {
#         "id": 21011,
#         "name": "#124",
#         "lat": 41.284235,
#         "lon": -72.957254,
#         "heading": 164,
#         "route": 8,
#         "lastStop": 123,
#         "lastUpdate": 1711555414
#     },
#     {
#         "id": 21015,
#         "name": "#306",
#         "lat": 41.302403,
#         "lon": -72.923494,
#         "heading": 9,
#         "route": 3,
#         "lastStop": 38,
#         "lastUpdate": 1711555414
#     },
#     {
#         "id": 21016,
#         "name": "#43",
#         "lat": 41.308195,
#         "lon": -72.931864,
#         "heading": 27,
#         "route": 1,
#         "lastStop": 2,
#         "lastUpdate": 1711555410
#     },
#     {
#         "id": 21020,
#         "name": "#39",
#         "lat": 41.301944,
#         "lon": -72.933361,
#         "heading": 249,
#         "route": 1,
#         "lastStop": 43,
#         "lastUpdate": 1711555411
#     },
#     {
#         "id": 21021,
#         "name": "#57",
#         "lat": 41.308337,
#         "lon": -72.927951,
#         "heading": 209,
#         "route": 2,
#         "lastStop": 98,
#         "lastUpdate": 1711555415
#     },
#     {
#         "id": 21022,
#         "name": "#47",
#         "lat": 41.318016,
#         "lon": -72.919721,
#         "heading": 198,
#         "route": 1,
#         "lastStop": 138,
#         "lastUpdate": 1711555407
#     },
#     {
#         "id": 21023,
#         "name": "#126",
#         "lat": 41.32403,
#         "lon": -72.928848,
#         "heading": 187,
#         "route": 3,
#         "lastStop": 27,
#         "lastUpdate": 1711555414
#     },
#     {
#         "id": 21024,
#         "name": "#118",
#         "lat": 41.30051,
#         "lon": -72.930082,
#         "heading": 82,
#         "route": 3,
#         "lastStop": 13,
#         "lastUpdate": 1711555409
#     },
#     {
#         "id": 21027,
#         "name": "#323",
#         "lat": 41.3011,
#         "lon": -72.925793,
#         "heading": 106,
#         "route": 10,
#         "lastStop": 122,
#         "lastUpdate": 1711555414
#     },
#     {
#         "id": 21028,
#         "name": "#324",
#         "lat": 41.315814,
#         "lon": -72.922909,
#         "heading": 105,
#         "route": 11,
#         "lastStop": 106,
#         "lastUpdate": 1711555410
#     }
# ]

# %%
data
# Out:
# [{'id': 20998,
#   'name': '#330',
#   'lat': 41.323018,
#   'lon': -72.913891,
#   'heading': 299,
#   'route': 9,
#   'lastStop': 143,
#   'lastUpdate': 1711555413},
#  {'id': 21002,
#   'name': '#314',
#   'lat': 41.255718,
#   'lon': -72.994077,
#   'heading': 202,
#   'route': 9,
#   'lastStop': 22,
#   'lastUpdate': 1711555414},
#  {'id': 21004,
#   'name': '#308',
#   'lat': 41.303727,
#   'lon': -72.93165,
#   'heading': 124,
#   'route': 8,
#   'lastStop': 72,
#   'lastUpdate': 1711555409},
#  {'id': 21005,
#   'name': '#329',
#   'lat': 41.255897,
#   'lon': -72.990143,
#   'heading': 216,
#   'route': 10,
#   'lastStop': 23,
#   'lastUpdate': 1711555414},
#  {'id': 21007,
#   'name': '#316',
#   'lat': 41.297921,
#   'lon': -72.926713,
#   'heading': 40,
#   'route': 12,
#   'lastStop': 98,
#   'lastUpdate': 1711555414},
#  {'id': 21008,
#   'name': '#317',
#   'lat': 41.324905,
#   'lon': -72.928296,
#   'heading': 343,
#   'route': 3,
#   'lastStop': 27,
#   'lastUpdate': 1711555408},
#  {'id': 21011,
#   'name': '#124',
#   'lat': 41.284235,
#   'lon': -72.957254,
#   'heading': 164,
#   'route': 8,
#   'lastStop': 123,
#   'lastUpdate': 1711555414},
#  {'id': 21015,
#   'name': '#306',
#   'lat': 41.302403,
#   'lon': -72.923494,
#   'heading': 9,
#   'route': 3,
#   'lastStop': 38,
#   'lastUpdate': 1711555414},
#  {'id': 21016,
#   'name': '#43',
#   'lat': 41.308195,
#   'lon': -72.931864,
#   'heading': 27,
#   'route': 1,
#   'lastStop': 2,
#   'lastUpdate': 1711555410},
#  {'id': 21020,
#   'name': '#39',
#   'lat': 41.301944,
#   'lon': -72.933361,
#   'heading': 249,
#   'route': 1,
#   'lastStop': 43,
#   'lastUpdate': 1711555411},
#  {'id': 21021,
#   'name': '#57',
#   'lat': 41.308337,
#   'lon': -72.927951,
#   'heading': 209,
#   'route': 2,
#   'lastStop': 98,
#   'lastUpdate': 1711555415},
#  {'id': 21022,
#   'name': '#47',
#   'lat': 41.318016,
#   'lon': -72.919721,
#   'heading': 198,
#   'route': 1,
#   'lastStop': 138,
#   'lastUpdate': 1711555407},
#  {'id': 21023,
#   'name': '#126',
#   'lat': 41.32403,
#   'lon': -72.928848,
#   'heading': 187,
#   'route': 3,
#   'lastStop': 27,
#   'lastUpdate': 1711555414},
#  {'id': 21024,
#   'name': '#118',
#   'lat': 41.30051,
#   'lon': -72.930082,
#   'heading': 82,
#   'route': 3,
#   'lastStop': 13,
#   'lastUpdate': 1711555409},
#  {'id': 21027,
#   'name': '#323',
#   'lat': 41.3011,
#   'lon': -72.925793,
#   'heading': 106,
#   'route': 10,
#   'lastStop': 122,
#   'lastUpdate': 1711555414},
#  {'id': 21028,
#   'name': '#324',
#   'lat': 41.315814,
#   'lon': -72.922909,
#   'heading': 105,
#   'route': 11,
#   'lastStop': 106,
#   'lastUpdate': 1711555410}]
